# %% [markdown]
# ## 0. 학습 세팅

# %%
# !pip install torchmetrics
# !pip install foolbox

# %% [markdown]
# ### 1) 메모리 정리

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ### 2) 수정된 코드 자동 업데이트

# %%
# %load_ext autoreload
# %autoreload 2
import foolbox as fb

# %%
from google.colab import drive

# Mount goole drive
drive.mount('/content/drive')

# Move to the project directory

#===================구글 드라이브 경로==================================================
# %cd /content/drive/MyDrive/RetinaProject_final/RetinaProject
#==================================================================================
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/RetinaProject_final/RetinaProject
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.7/dist-packages (0.10.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.1.1)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.12.1+cu113)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)

# %% [markdown]
# ## 1. Load library

# %%
import os
import time
import copy
"""
import json
import glob

import numpy as np
from PIL import Image

from torchmetrics.aggregation import MeanMetric
"""
import argparse
import easydict

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
"""
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as Datasets
"""
import torchvision.transforms as T

from torch.utils.tensorboard import SummaryWriter
"""
import torch.utils.data as data
"""
from torch.utils.data import Dataset, DataLoader, random_split
from torchmetrics.functional.classification import accuracy

from src.models import vgg11_config, vgg13_config, vgg16_config
from src.models import VGG, get_vgg_layers
from src.engines import train, evaluate, get_predictions
from src.engines import plot_most_correct_wrong, epoch_time, normalize_image
from src.utils import load_checkpoint, save_checkpoint, save_transform
import sys

sys.setrecursionlimit(10**7)
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ## 2. Variable Declaration

# %%
# # Jupyter 외 환경
# parser = argparse.ArgumentParser()
# parser.add_argument("--title", type=str, default="baseline")
# parser.add_argument("--device", type=str, default="cuda")
# parser.add_argument("--root", type=str, default="data")
# parser.add_argument("--batch_size", type=int, default=64)
# parser.add_argument("--num_workers", type=int, default=2)
# parser.add_argument("--epochs", type=int, default=100)
# parser.add_argument("--lr", type=float, default=0.001)
# parser.add_argument("--logs", type=str, default='logs')
# parser.add_argument("--checkpoints", type=str, default='checkpoints')
# parser.add_argument("--resume", type=bool, default=False)
# args = parser.parse_args()

# Jupyter 환경
args = easydict.EasyDict({
        "title" : "Retina_ML_7.5r1e-5_Aug3_NoiseStudent",
        #==============baseline 최고성능 모델 title======================
        "load_model" : "Retina_ML_7.5r1e-5_Aug3",
        #=================================================================
        "device" : "cuda",
        "root" : "data",
        "batch_size" : 32, # !!!
        "num_workers" : 2,
        "epochs" : 100, # !!!
        "lr" : 7.5e-5, # !!!
        "logs" : "logs",
        "checkpoints" : "checkpoints",
        "transform_dir" : "transform_infor",
        "resume" : False,
        "train_ratio" : 0.8,
        "val_ratio" : 0.2,
        "test_ratio" : 1.0,
        "output_dim" : 2
    })

# %% [markdown]
# ## 3. Image Data Preprocessing

# %% [markdown]
# ### 1) 이미지 변환

# %%
"""
# Load Dataset
class RetinaDataset(Dataset):
    # image dataset 전체 경로 저장 -> tranform
    def __init__(self, root, transform=None):
        super(RetinaDataset, self).__init__()
        self.make_dataset(root)
        self.transform = transform
    
    # image dataset 전체 경로 저장
    def make_dataset(self, root):
        # class(폴더명) 불러오기
        self.data = []
        categories = os.listdir(root)
        categories = sorted(categories)
        
        # class -> label 변환 + 각 class의 이미지 파일 전부 가져오기
        for label, category in enumerate(categories):
            images = glob.glob(f'{root}/{category}/*.png')
            for image in images:
                self.data.append((image, label))
    
    # data 개수
    def __len__(self):
        return len(self.data)
    
    # 경로에 있는, 지정한 idx의 이미지 읽기 -> RGB 변환 -> tranform -> image, label 반환
    def __getitem__(self, idx):
        image, label = self.data[idx]
        image = self.read_image(image)
        if self.transform is not None:
            image = self.transform(image)
        return image, label
    
    # 경로에 있는 image 읽기 -> RGB 변환
    def read_image(self, path):
        image = Image.open(path)
        return image.convert('RGB')
"""

# Build dataset
"""
# train, val, test dataset load + make loader
transform = T.Compose([
    T.ToTensor(),
    T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
]) # transform을 train과 test 따로따로 설정해줘야하나?

dataset_root = "data/Retina"
dataset = RetinaDataset(dataset_root, transform)
train_size = int(dataset_size * args.train_ratio)
val_size = int(dataset_size * args.val_ratio)
test_size = dataset_size - train_size - val_size # random_split에서 dataset_size = train_size + val_size + test_size가 되지 않으면 오류 발생

print("[dataset load complete]") # 확인용 코드

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=args.batch_size, num_workers=args.num_workers, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=args.batch_size, num_workers=args.num_workers, shuffle=True, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=args.batch_size, num_workers=args.num_workers, shuffle=False, drop_last=False)

# 확인용 코드
print(f"Training Data Size : {len(train_dataset)}")
print(f"Validation Data Size : {len(val_dataset)}")
print(f"Testing Data Size : {len(test_dataset)}")

print(f"train_dataset 개수 : {len(train_dataset)}, " + f"train_loader 개수 : {len(train_loader)}") # train_data 개수, train_loader batch set 개수
print(f"val_dataset 개수 : {len(val_dataset)}, " + f"val_loader 개수 : {len(val_loader)}") # val_data 개수, val_loader batch set 개수
print(f"test_dataset 개수 : {len(test_dataset)}, " + f"test_loader 개수 : {len(test_loader)}") # test_data 개수, test_loader batch set 개수

# Build model
model = ConvNet()
model = model.to(args.device)
"""
# 이미지 변환
train_transforms = T.Compose([
    T.Resize((256, 256)), # 이미지 크기 재조절
    T.RandomOrder([
        # T.RandomRotation(5), # 이미지 회전(5도 이하)
        # T.RandomHorizontalFlip(0.5), # 이미지 좌우 대칭(50% 확률)
#         T.RandomRotation(180),
        T.RandomHorizontalFlip(),
        T.RandomVerticalFlip(),
        T.RandomAutocontrast(),
#         T.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 5)),
#         T.RandomAffine(180, shear=20),
#         T.RandomPerspective(fill=[255,255,255]),
#         T.RandomGrayscale(p=0.5),
#         T.RandomResizedCrop((256, 256)),
    ]),
    T.ToTensor(),
    T.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

test_transforms = T.Compose([
    T.Resize((256, 256)), 
    T.ToTensor(),
    T.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

#==================================================================================================
stu_transforms = T.Compose([
    T.Resize((256, 256)),
    T.RandomOrder([
        T.RandomHorizontalFlip(),
        T.RandomVerticalFlip(),
        T.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 5)),
        T.RandomGrayscale(p=0.2),
        T.RandomInvert(p = 0.2),
        T.RandomPosterize(1),
        T.RandomEqualize(p = 0.5)
    ]),
    T.ToTensor(),
    T.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])
#==================================================================================================

# transform 정보 저장
save_transform(args.transform_dir, train_transforms, test_transforms, args.title)

# %% [markdown]
# ### 2) 이미지 데이터셋 불러오기 + 이미지 변환

# %%
#==================================원본 망막 데이터 경로=======================================================
train_path = "/content/drive/MyDrive/RetinaProject_final/RetinaProject/data/Retina_Some_binary/train"
test_path = "/content/drive/MyDrive/RetinaProject_final/RetinaProject/data/Retina_Some_binary/test"
#==============================================================================================================


train_dataset = torchvision.datasets.ImageFolder(
    train_path, 
    transform = train_transforms
)
test_dataset = torchvision.datasets.ImageFolder(
    test_path, 
    transform = test_transforms
)

print("len(train_dataset) : ", len(train_dataset))
print("len(test_dataset) : ", len(test_dataset))

#==================================================================================================

#======================================크롤링 데이터 저장 경로====================================
stu_path = "/content/drive/MyDrive/RetinaProject_final/RetinaProject/data/StudentData"
#=================================================================================================


stu_dataset1 = torchvision.datasets.ImageFolder(
    stu_path, 
    transform = stu_transforms
)

stu_dataset2 = torchvision.datasets.ImageFolder(
    stu_path, 
    transform = stu_transforms
)

stu_dataset3 = torchvision.datasets.ImageFolder(
    stu_path, 
    transform = stu_transforms
)

stu_dataset = stu_dataset1 + stu_dataset2 + stu_dataset3

print("len(stu_dataset1) : ", len(stu_dataset1))
print("len(stu_dataset2) : ", len(stu_dataset2))
print("len(stu_dataset3) : ", len(stu_dataset3))
#==================================================================================================
# Out:
# len(train_dataset) :  4532
# len(test_dataset) :  1132
# len(stu_dataset1) :  2000
# len(stu_dataset2) :  2000
# len(stu_dataset3) :  2000

# %% [markdown]
# ### 3) 훈련, 검증 데이터 분할 + 검증 이미지 재변환

# %%
all_train_dataset_size = len(train_dataset)
train_dataset_size = int(all_train_dataset_size * args.train_ratio)
valid_dataset_size = all_train_dataset_size - train_dataset_size

splited_train_dataset, splited_valid_dataset = random_split(train_dataset, [train_dataset_size, valid_dataset_size]) # 훈련 데이터셋, 검증 데이터셋 크기 결정

# %%
splited_valid_dataset = copy.deepcopy(splited_valid_dataset)
splited_valid_dataset.dataset.transform = test_transforms

# %% [markdown]
# ### 4) 데이터 로드 to 메모리

# %% [markdown]
# ## 4. Model Define

# %% [markdown]
# ### 1) 모델 정의

# %%
# Build model
vgg11_layers = get_vgg_layers(vgg11_config, batch_norm = True)
model = VGG(vgg11_layers, args.output_dim)
model = model.to(args.device)

# %% [markdown]
# ### +) 학생 모델 -> 선생 모델 이동

# %%
#==================================================================================================

#===================================================학습된 baseline 모델 불러오기========================================================
model.load_state_dict(torch.load(f"/content/drive/MyDrive/RetinaProject_final/RetinaProject/best_valid_model/{args.load_model}.pt"))
#========================================================================================================================================

model.eval()

train_dataset_stu = copy.deepcopy(train_dataset)
for i in range(len(stu_dataset)):
    model.eval()
    ima = stu_dataset[i][0].unsqueeze(0)
    ima = ima.cuda()
    if model(ima)[0][0] >= 0.0:
        idx = [[1]]
        idx[0][0] = stu_dataset[i][0]
        idx[0].append(0)
        a = tuple(idx)
        train_dataset_stu = train_dataset_stu + a
    elif model(ima)[0][0] <= 0.0:
        idx = [[1]]
        idx[0][0] = stu_dataset[i][0]
        idx[0].append(1)
        a = tuple(idx)
        train_dataset_stu = train_dataset_stu + a
#==================================================================================================

# %%
print(len(train_dataset))
print(len(train_dataset_stu))
# Out:
# 4532
# 10532

# %%
all_train_dataset_size_stu = len(train_dataset_stu)
train_dataset_size_stu = int(all_train_dataset_size_stu * args.train_ratio)
valid_dataset_size_stu = all_train_dataset_size_stu - train_dataset_size_stu

splited_train_dataset_stu, splited_valid_dataset_stu = random_split(train_dataset_stu, [train_dataset_size_stu, valid_dataset_size_stu]) # 훈련 데이터셋, 검증 데이터셋 크기 결정

# %%
print(len(splited_train_dataset_stu))
print(len(splited_valid_dataset_stu))
# Out:
# 8425
# 2107

# %%
splited_valid_dataset_stu.dataset.transform = test_transforms

# %%
train_loader_stu = DataLoader(splited_train_dataset_stu,
                            shuffle = True,
                            batch_size = args.batch_size, 
                            num_workers=args.num_workers
                        )
val_loader_stu = DataLoader(splited_valid_dataset_stu,
                            batch_size = args.batch_size,
                            num_workers=args.num_workers
                        )
test_loader = DataLoader(test_dataset,
                            batch_size = args.batch_size,
                            num_workers=args.num_workers
                        )

print(f"train_dataset 개수 : {len(splited_train_dataset_stu)}, " + f"train_loader 개수 : {len(train_loader_stu)}") # train_data 개수, train_loader batch set 개수
print(f"val_dataset 개수 : {len(splited_valid_dataset_stu)}, " + f"val_loader 개수 : {len(val_loader_stu)}") # val_data 개수, val_loader batch set 개수
print(f"test_dataset 개수 : {len(test_dataset)}, " + f"test_loader 개수 : {len(test_loader)}") # test_data 개수, test_loader batch set 개수
# Out:
# train_dataset 개수 : 8425, train_loader 개수 : 264
# val_dataset 개수 : 2107, val_loader 개수 : 66
# test_dataset 개수 : 1132, test_loader 개수 : 36

# %% [markdown]
# ### 2) 옵티마이저 + 손실함수 + 스케쥴러 + 메트릭 함수 정의

# %%
# Build optimizer 
optimizer = optim.Adam(model.parameters(), lr=args.lr)

# Build scheduler
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, args.epochs * len(train_loader_stu))

# Build loss function
loss_fn = nn.CrossEntropyLoss()

# Build metric function
"""
# 정확도 측정 함수
def calculate_accuracy(y_pred, y): # ???
    top_pred = y_pred.argmax(1, keepdim = True)
    # print("top_pred : ", top_pred)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    # print("correct : ", correct)
    acc = correct.float() / y.shape[0]
    # print("acc : ", acc)
    return acc
"""
metric_fn = accuracy

# %% [markdown]
# ### 3) logger 정의

# %%
# Build logger
train_logger = SummaryWriter(f'{args.logs}/train/{args.title}')
val_logger = SummaryWriter(f'{args.logs}/val/{args.title}')
test_logger = SummaryWriter(f'{args.logs}/test/{args.title}')

# %% [markdown]
# ## 5. Model Train

# %% [markdown]
# ### 1) Load model epoch

# %%
# Load model
start_epoch = 0
if args.resume:
    start_epoch = load_checkpoint(args.checkpoints, args.title, model, optimizer)

# %% [markdown]
# ### 2) Train model

# %%
best_valid_loss = float('inf')
for epoch in range(start_epoch, args.epochs):
    """
    # start timer
    start_time = time.time() # 확인용 코드
    """
    # 모델 학습 소요시간
    start_time = time.monotonic()

    # train one epoch + evaluate one epoch
    train_summary = train(train_loader_stu, model, optimizer, scheduler, loss_fn, metric_fn, args.device)
    val_summary = evaluate(val_loader_stu, model, loss_fn, metric_fn, args.device)

    # write log
    train_logger.add_scalar('Loss', train_summary['loss'], epoch + 1)
    train_logger.add_scalar('Accuracy', train_summary['metric'], epoch + 1)
    val_logger.add_scalar('Loss', val_summary['loss'], epoch + 1)
    val_logger.add_scalar('Accuracy', val_summary['metric'], epoch + 1)

    # 최적 loss인 model 저장
    if val_summary['loss'] < best_valid_loss:
        best_valid_loss = val_summary['loss']
        #====================================================학습 모델 저장 경로===============================================================
        torch.save(model.state_dict(), f"/content/drive/MyDrive/RetinaProject_final/RetinaProject/NoiseStudent_model/{args.title}.pt")
        #======================================================================================================================================

    # save model
    save_checkpoint(args.checkpoints, args.title, model, optimizer, epoch + 1)

    # 모델 학습 소요시간
    end_time = time.monotonic()
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    # Print log
    """
    print((
        f'[Epoch {epoch+1}] '
        + f'{epoch + 1}epoch time {end_time - start_time:.02f}, '
        + f'Train Loss {train_summary["loss"]:.04f}, '
        + f'Train Accuracy {train_summary["metric"]:.04f}, '
        + f'Test Loss {val_summary["loss"]:.04f}, '
        + f'Test Accuracy {val_summary["metric"]:.04f}'
    ))
    """
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\t Train Loss: {train_summary["loss"]:.3f} | Train Acc: {train_summary["metric"]:.2f}%')
    print(f'\t Valid Loss: {val_summary["loss"]:.3f} | Valid Acc: {val_summary["metric"]:.2f}%')
    print(f'\t scheduled_lr : {scheduler.get_last_lr()[0]}')
# Out:
# Epoch: 01 | Epoch Time: 13m 6s
# 	 Train Loss: 0.648 | Train Acc: 0.64%
# 	 Valid Loss: 0.635 | Valid Acc: 0.66%
# 	 scheduled_lr : 7.498149601371492e-05
# Epoch: 02 | Epoch Time: 0m 36s
# 	 Train Loss: 0.634 | Train Acc: 0.65%
# 	 Valid Loss: 0.655 | Valid Acc: 0.61%
# 	 scheduled_lr : 7.492600231606014e-05
# Epoch: 03 | Epoch Time: 0m 34s
# 	 Train Loss: 0.625 | Train Acc: 0.66%
# 	 Valid Loss: 0.638 | Valid Acc: 0.64%
# 	 scheduled_lr : 7.483357367261551e-05
# Epoch: 04 | Epoch Time: 0m 36s
# 	 Train Loss: 0.618 | Train Acc: 0.66%
# 	 Valid Loss: 0.628 | Valid Acc: 0.66%
# 	 scheduled_lr : 7.470430129929282e-05
# Epoch: 05 | Epoch Time: 0m 39s
# 	 Train Loss: 0.614 | Train Acc: 0.66%
# 	 Valid Loss: 0.626 | Valid Acc: 0.66%
# 	 scheduled_lr : 7.453831277231758e-05
# Epoch: 06 | Epoch Time: 0m 38s
# 	 Train Loss: 0.614 | Train Acc: 0.66%
# 	 Valid Loss: 0.632 | Valid Acc: 0.66%
# 	 scheduled_lr : 7.433577190232583e-05
# Epoch: 07 | Epoch Time: 0m 36s
# 	 Train Loss: 0.606 | Train Acc: 0.67%
# 	 Valid Loss: 0.632 | Valid Acc: 0.67%
# 	 scheduled_lr : 7.409687857270301e-05
# Epoch: 08 | Epoch Time: 0m 35s
# 	 Train Loss: 0.602 | Train Acc: 0.67%
# 	 Valid Loss: 0.632 | Valid Acc: 0.67%
# 	 scheduled_lr : 7.382186854232367e-05
# Epoch: 09 | Epoch Time: 0m 35s
# 	 Train Loss: 0.599 | Train Acc: 0.68%
# 	 Valid Loss: 0.637 | Valid Acc: 0.66%
# 	 scheduled_lr : 7.35110132128854e-05
| Valid Acc: 0.62%
# 	 scheduled_lr : 1.664263273844989e-07
# Epoch: 98 | Epoch Time: 0m 37s
# 	 Train Loss: 0.103 | Train Acc: 0.96%
# 	 Valid Loss: 2.964 | Valid Acc: 0.62%
# 	 scheduled_lr : 7.3997683939816e-08
# Epoch: 99 | Epoch Time: 0m 37s
# 	 Train Loss: 0.099 | Train Acc: 0.96%
# 	 Valid Loss: 2.940 | Valid Acc: 0.62%
# 	 scheduled_lr : 1.8503986285064862e-08
# Epoch: 100 | Epoch Time: 0m 36s
# 	 Train Loss: 0.104 | Train Acc: 0.96%
# 	 Valid Loss: 2.977 | Valid Acc: 0.61%
# 	 scheduled_lr : 0.0

# %% [markdown]
# ## 6. Model Test

# %%
# 학습된 모델 불러오기

#===============================================학습된 모델 저장 경로===================================================================
model.load_state_dict(torch.load(f"/content/drive/MyDrive/RetinaProject_final/RetinaProject/NoiseStudent_model/{args.title}.pt"))
#========================================================================================================================================


# 모델 성능 측정
test_summary = evaluate(test_loader, model, loss_fn, metric_fn, args.device)

# write log
test_logger.add_scalar('Loss', test_summary['loss'], epoch + 1)
test_logger.add_scalar('Accuracy', test_summary['metric'], epoch + 1)

print(f'Test Loss: {test_summary["loss"]:.3f} | Test Acc: {test_summary["metric"]:.2f}%')
# Out:
# Test Loss: 0.563 | Test Acc: 0.76%

# %% [markdown]
# ### 1) 예측한 값 추출 + 맞춘 이미지 정보 추출 + 틀린 이미지 정보 추출

# %%
correct_examples, wrong_examples = get_predictions(test_loader, model, args.device)

# %%
for correct_example in correct_examples: # 확인용 코드
    print("correct_example : ", correct_example[2])
for wrong_example in wrong_examples: # 확인용 코드
    print("wrong_example : ", wrong_example[2])
# Out:
# correct_example :  tensor([0.9404, 0.0596])
# correct_example :  tensor([0.9397, 0.0603])
# correct_example :  tensor([0.9267, 0.0733])
# correct_example :  tensor([0.9265, 0.0735])
# correct_example :  tensor([0.9262, 0.0738])
# correct_example :  tensor([0.9215, 0.0785])
# correct_example :  tensor([0.9133, 0.0867])
# correct_example :  tensor([0.9102, 0.0898])
# correct_example :  tensor([0.9084, 0.0916])
# correct_example :  tensor([0.9038, 0.0962])
# correct_example :  tensor([0.9027, 0.0973])
# correct_example :  tensor([0.8991, 0.1009])
# correct_example :  tensor([0.8987, 0.1013])
# correct_example :  tensor([0.8980, 0.1020])
# correct_example :  tensor([0.8965, 0.1035])
# correct_example :  tensor([0.8954, 0.1046])
# correct_example :  tensor([0.8934, 0.1066])
# correct_example :  tensor([0.8926, 0.1074])
# correct_example :  tensor([0.8906, 0.1094])
# correct_example :  tensor([0.8904, 0.1096])
# correct_example :  tensor([0.8895, 0.1105])
# correct_example :  tensor([0.8889, 0.1111])
# correct_example :  tensor([0.8888, 0.1112])
# correct_example :  tensor([0.8887, 0.1113])
# correct_example :  tensor([0.8877, 0.1123])
# correct_example :  tensor([0.8847, 0.1153])
# correct_example :  tensor([0.8834, 0.1166])
# correct_example :  tensor([0.8833, 0.1167])
# correct_example :  tensor([0.8825, 0.1175])
# correct_example :  tensor([0.8807, 0.1193])
# correct_example :  tensor([0.8806, 0.1194])
# correct_example :  tensor([0.8794, 0.1206])
# correct_example :  tensor([0.8793, 0.1207])
# correct_example :  tensor([0.8766, 0.1234])
# correct_example :  tensor([0.8749, 0.1251])
# correct_example :  tensor([0.8745, 0.1255])
# correct_example :  tensor([0.8738, 0.1262])
# correct_example :  tensor([0.8723, 0.1277])
# correct_example :  tensor([0.8702, 0.1298])
# correct_example :  tensor([0.8680, 0.1320])
# correct_example :  tensor([0.8678, 0.1322])
# correct_example :  tensor([0.8662, 0.1338])
# correct_example :  tensor([0.8653, 0.1347])
# correct_example :  tensor([0.8631, 0.1369])
# correct_example :  tensor([0.8605, 0.1395])
# correct_example :  tensor([0.8600, 0.1400])
# correct_example :  tensor([0.8593, 0.1407])
# correct_example :  tensor([0.8588, 0.1412])
# correct_example :  tensor([0.8581, 0.1419])
# correct_example :  tensor([0.8574, 0.1426])
# correct_example :  tensor([0.8562, 0.1438])
# correct_example :  tensor([0.8555, 0.1445])
# correct_example :  tensor([0.8513, 0.1487])
# correct_example :  tensor([0.8496, 0.1504])
# correct_example :  tensor([0.8496, 0.1504])
# correct_example :  tensor([0.8487, 0.1513])
# correct_example :  tensor([0.8475, 0.1525])
# correct_example :  tensor([0.8471, 0.1529])
# correct_example :  tensor([0.8469, 0.1531])
# correct_example :  tensor([0.8459, 0.1541])
# correct_example :  tensor([0.8452, 0.1548])
# correct_example :  tensor([0.8445, 0.1555])
# correct_example :  tensor([0.8418, 0.1582])
# correct_example :  tensor([0.8410, 0.1590])
# correct_example :  tensor([0.8410, 0.1590])
# correct_example :  tensor([0.8404, 0.1596])
# correct_example :  tensor([0.8402, 0.1598])
# correct_example :  tensor([0.8381, 0.1619])
# correct_example :  tensor([0.8373, 0.1627])
# correct_example :  tensor([0.8370, 0.1630])
# correct_example :  tensor([0.8333, 0.1667])
# correct_example :  tensor([0.8332, 0.1668])
# correct_example :  tensor([0.8330, 0.1670])
# correct_example :  tensor([0.8311, 0.1689])
# correct_example :  tensor([0.8302, 0.1698])
# correct_example :  tensor([0.8301, 0.1699])
# correct_example :  tensor([0.8297, 0.1703])
# correct_example :  tensor([0.8297, 0.1703])
# correct_example :  tensor([0.8296, 0.1704])
# correct_example :  tensor([0.8292, 0.1708])
# correct_example :  tensor([0.8278, 0.1722])
# correct_example :  tensor([0.8264, 0.1736])
# correct_example :  tensor([0.8259, 0.1741])
# correct_example :  tensor([0.8243, 0.1757])
# correct_example :  tensor([0.8236, 0.1764])
# correct_example :  tensor([0.8229, 0.1771])
# correct_example :  tensor([0.8220, 0.1780])
# correct_example :  tensor([0.8207, 0.1793])
# correct_example :  tensor([0.8201, 0.1799])
# correct_example :  tensor([0.8189, 0.1811])
# correct_example :  tensor([0.8186, 0.1814])
# correct_example :  tensor([0.8179, 0.1821])
# correct_example :  tensor([0.8176, 0.1824])
# correct_example :  tensor([0.8169, 0.1831])
# correct_example :  tensor([0.8165, 0.1835])
# correct_example :  tensor([0.8152, 0.1848])
# correct_example :  tensor([0.8132, 0.1868])
# correct_example :  tensor([0.8126, 0.1874])
# correct_example :  tensor([0.8122, 0.1878])
# correct_example :  tensor([0.8122, 0.1878])
# correct_example :  tensor([0.8114, 0.1886])
# correct_example :  tensor([0.8112, 0.1888])
# correct_example :  tensor([0.8107, 0.1893])
# correct_example :  tensor([0.8103, 0.1897])
# correct_example :  tensor([0.8091, 0.1909])
# correct_example :  tensor([0.8086, 0.1914])
# correct_example :  tensor([0.8067, 0.1933])
# correct_example :  tensor([0.8044, 0.1956])
# correct_example :  tensor([0.8039, 0.1961])
# correct_example :  tensor([0.8038, 0.1962])
# correct_example :  tensor([0.8038, 0.1962])
# correct_example :  tensor([0.8037, 0.1963])
# correct_example :  tensor([0.8031, 0.1969])
# correct_example :  tensor([0.8029, 0.1971])
# correct_example :  tensor([0.8024, 0.1976])
# correct_example :  tensor([0.8002, 0.1998])
# correct_example :  tensor([0.7985, 0.2015])
# correct_example :  tensor([0.7984, 0.2016])
# correct_example :  tensor([0.7976, 0.2024])
# correct_example :  tensor([0.7973, 0.2027])
# correct_example :  tensor([0.7967, 0.2033])
# correct_example :  tensor([0.7967, 0.2033])
# correct_example :  tensor([0.7961, 0.2039])
# correct_example :  tensor([0.7958, 0.2042])
# correct_example :  tensor([0.7942, 0.2058])
# correct_example :  tensor([0.7920, 0.2080])
# correct_example :  tensor([0.7920, 0.2080])
# correct_example :  tensor([0.7894, 0.2106])
# correct_example :  tensor([0.7884, 0.2116])
# correct_example :  tensor([0.7876, 0.2124])
# correct_example :  tensor([0.7870, 0.2130])
# correct_example :  tensor([0.7866, 0.2134])
# correct_example :  tensor([0.7848, 0.2152])
# correct_example :  tensor([0.7846, 0.2154])
# correct_example :  tensor([0.7845, 0.2155])
# correct_example :  tensor([0.7840, 0.2160])
# correct_example :  tensor([0.7840, 0.2160])
# correct_example :  tensor([0.7820, 0.2180])
# correct_example :  tensor([0.7809, 0.2191])
# correct_example :  tensor([0.7809, 0.2191])
# correct_example :  tensor([0.7800, 0.2200])
# correct_example :  tensor([0.7782, 0.2218])
# correct_example :  tensor([0.7782, 0.2218])
# correct_example :  tensor([0.7766, 0.2234])
# correct_example :  tensor([0.7765, 0.2235])
# correct_example :  tensor([0.7749, 0.2251])
# correct_example :  tensor([0.7749, 0.2251])
# correct_example :  tensor([0.7725, 0.2275])
# correct_example :  tensor([0.7720, 0.2280])
# correct_example :  tensor([0.7719, 0.2281])
# correct_example :  tensor([0.7716, 0.2284])
# correct_example :  tensor([0.7711, 0.2289])
# correct_example :  tensor([0.7707, 0.2293])
# correct_example :  tensor([0.7703, 0.2297])
# correct_example :  tensor([0.7703, 0.2297])
# correct_example :  tensor([0.7683, 0.2317])
# correct_example :  tensor([0.7683, 0.2317])
# correct_example :  tensor([0.7676, 0.2324])
# correct_example :  tensor([0.7672, 0.2328])
# correct_example :  tensor([0.7671, 0.2329])
# correct_example :  tensor([0.7658, 0.2342])
# correct_example :  tensor([0.7648, 0.2352])
# correct_example :  tensor([0.7632, 0.2368])
# correct_example :  tensor([0.7620, 0.2380])
# correct_example :  tensor([0.7619, 0.2381])
# correct_example :  tensor([0.7613, 0.2387])
# correct_example :  tensor([0.7606, 0.2394])
# correct_example :  tensor([0.7592, 0.2408])
# correct_example :  tensor([0.7589, 0.2411])
# correct_example :  tensor([0.7588, 0.2412])
# correct_example :  tensor([0.7575, 0.2425])
# correct_example :  tensor([0.7566, 0.2434])
# correct_example :  tensor([0.7548, 0.2452])
# correct_example :  tensor([0.7547, 0.2453])
# correct_example :  tensor([0.7533, 0.2467])
# correct_example :  tensor([0.7524, 0.2476])
# correct_example :  tensor([0.7501, 0.2499])
# correct_example :  tensor([0.7456, 0.2544])
# correct_example :  tensor([0.7451, 0.2549])
# correct_example :  tensor([0.7441, 0.2559])
# correct_example :  tensor([0.7437, 0.2563])
# correct_example :  tensor([0.7432, 0.2568])
# correct_example :  tensor([0.7430, 0.2570])
# correct_example :  tensor([0.7424, 0.2576])
# correct_example :  tensor([0.7410, 0.2590])
# correct_example :  tensor([0.7392, 0.2608])
# correct_example :  tensor([0.7381, 0.2619])
# correct_example :  tensor([0.7378, 0.2622])
# correct_example :  tensor([0.7348, 0.2652])
# correct_example :  tensor([0.7339, 0.2661])
# correct_example :  tensor([0.7338, 0.2662])
# correct_example :  tensor([0.7327, 0.2673])
# correct_example :  tensor([0.7322, 0.2678])
# correct_example :  tensor([0.7317, 0.2683])
# correct_example :  tensor([0.7296, 0.2704])
# correct_example :  tensor([0.7295, 0.2705])
# correct_example :  tensor([0.7286, 0.2714])
# correct_example :  tensor([0.7283, 0.2717])
# correct_example :  tensor([0.7263, 0.2737])
# correct_example :  tensor([0.7257, 0.2743])
# correct_example :  tensor([0.7231, 0.2769])
# correct_example :  tensor([0.7227, 0.2773])
# correct_example :  tensor([0.7216, 0.2784])
# correct_example :  tensor([0.7205, 0.2795])
# correct_example :  tensor([0.7198, 0.2802])
# correct_example :  tensor([0.7198, 0.2802])
# correct_example :  tensor([0.7190, 0.2810])
# correct_example :  tensor([0.7186, 0.2814])
# correct_example :  tensor([0.7174, 0.2826])
# correct_example :  tensor([0.7162, 0.2838])
# correct_example :  tensor([0.7160, 0.2840])
# correct_example :  tensor([0.7157, 0.2843])
# correct_example :  tensor([0.7154, 0.2846])
# correct_example :  tensor([0.7152, 0.2848])
# correct_example :  tensor([0.7149, 0.2851])
# correct_example :  tensor([0.7126, 0.2874])
# correct_example :  tensor([0.7121, 0.2879])
# correct_example :  tensor([0.2911, 0.7089])
# correct_example :  tensor([0.7084, 0.2916])
# correct_example :  tensor([0.7064, 0.2936])
# correct_example :  tensor([0.7062, 0.2938])
# correct_example :  tensor([0.7057, 0.2943])
# correct_example :  tensor([0.7041, 0.2959])
# correct_example :  tensor([0.7032, 0.2968])
# correct_example :  tensor([0.7019, 0.2981])
# correct_example :  tensor([0.7016, 0.2984])
# correct_example :  tensor([0.6996, 0.3004])
# correct_example :  tensor([0.6972, 0.3028])
# correct_example :  tensor([0.6970, 0.3030])
# correct_example :  tensor([0.6969, 0.3031])
# correct_example :  tensor([0.6969, 0.3031])
# correct_example :  tensor([0.6964, 0.3036])
# correct_example :  tensor([0.6951, 0.3049])
# correct_example :  tensor([0.6943, 0.3057])
# correct_example :  tensor([0.6939, 0.3061])
# correct_example :  tensor([0.6937, 0.3063])
# correct_example :  tensor([0.6923, 0.3077])
# correct_example :  tensor([0.6921, 0.3079])
# correct_example :  tensor([0.6912, 0.3088])
# correct_example :  tensor([0.6904, 0.3096])
# correct_example :  tensor([0.6889, 0.3111])
# correct_example :  tensor([0.6888, 0.3112])
# correct_example :  tensor([0.6886, 0.3114])
# correct_example :  tensor([0.6875, 0.3125])
# correct_example :  tensor([0.6867, 0.3133])
# correct_example :  tensor([0.6861, 0.3139])
# correct_example :  tensor([0.6859, 0.3141])
# correct_example :  tensor([0.6855, 0.3145])
# correct_example :  tensor([0.6851, 0.3149])
# correct_example :  tensor([0.6850, 0.3150])
# correct_example :  tensor([0.3172, 0.6828])
# correct_example :  tensor([0.6827, 0.3173])
# correct_example :  tensor([0.6821, 0.3179])
# correct_example :  tensor([0.6815, 0.3185])
# correct_example :  tensor([0.6811, 0.3189])
# correct_example :  tensor([0.6799, 0.3201])
# correct_example :  tensor([0.6780, 0.3220])
# correct_example :  tensor([0.6777, 0.3223])
# correct_example :  tensor([0.6757, 0.3243])
# correct_example :  tensor([0.6730, 0.3270])
# correct_example :  tensor([0.3278, 0.6722])
# correct_example :  tensor([0.6721, 0.3279])
# correct_example :  tensor([0.6706, 0.3294])
# correct_example :  tensor([0.6693, 0.3307])
# correct_example :  tensor([0.6688, 0.3312])
# correct_example :  tensor([0.6684, 0.3316])
# correct_example :  tensor([0.6672, 0.3328])
# correct_example :  tensor([0.6671, 0.3329])
# correct_example :  tensor([0.3334, 0.6666])
# correct_example :  tensor([0.6655, 0.3345])
# correct_example :  tensor([0.6650, 0.3350])
# correct_example :  tensor([0.6629, 0.3371])
# correct_example :  tensor([0.6628, 0.3372])
# correct_example :  tensor([0.6625, 0.3375])
# correct_example :  tensor([0.6611, 0.3389])
# correct_example :  tensor([0.6604, 0.3396])
# correct_example :  tensor([0.6596, 0.3404])
# correct_example :  tensor([0.6595, 0.3405])
# correct_example :  tensor([0.6586, 0.3414])
# correct_example :  tensor([0.6579, 0.3421])
# correct_example :  tensor([0.6560, 0.3440])
# correct_example :  tensor([0.6560, 0.3440])
# correct_example :  tensor([0.6555, 0.3445])
# correct_example :  tensor([0.6549, 0.3451])
# correct_example :  tensor([0.6548, 0.3452])
# correct_example :  tensor([0.6539, 0.3461])
# correct_example :  tensor([0.6524, 0.3476])
# correct_example :  tensor([0.3481, 0.6519])
# correct_example :  tensor([0.6516, 0.3484])
# correct_example :  tensor([0.6512, 0.3488])
# correct_example :  tensor([0.3491, 0.6509])
# correct_example :  tensor([0.6509, 0.3491])
# correct_example :  tensor([0.6508, 0.3492])
# correct_example :  tensor([0.6490, 0.3510])
# correct_example :  tensor([0.3512, 0.6488])
# correct_example :  tensor([0.6476, 0.3524])
# correct_example :  tensor([0.6476, 0.3524])
# correct_example :  tensor([0.6471, 0.3529])
# correct_example :  tensor([0.6468, 0.3532])
# correct_example :  tensor([0.3546, 0.6454])
# correct_example :  tensor([0.3551, 0.6449])
# correct_example :  tensor([0.6428, 0.3572])
# correct_example :  tensor([0.3594, 0.6406])
# correct_example :  tensor([0.6405, 0.3595])
# correct_example :  tensor([0.3598, 0.6402])
# correct_example :  tensor([0.6395, 0.3605])
# correct_example :  tensor([0.6379, 0.3621])
# correct_example :  tensor([0.6378, 0.3622])
# correct_example :  tensor([0.6367, 0.3633])
# correct_example :  tensor([0.6364, 0.3636])
# correct_example :  tensor([0.6359, 0.3641])
# correct_example :  tensor([0.3653, 0.6347])
# correct_example :  tensor([0.3674, 0.6326])
# correct_example :  tensor([0.3676, 0.6324])
# correct_example :  tensor([0.6317, 0.3683])
# correct_example :  tensor([0.3694, 0.6306])
# correct_example :  tensor([0.6303, 0.3697])
# correct_example :  tensor([0.3698, 0.6302])
# correct_example :  tensor([0.6301, 0.3699])
# correct_example :  tensor([0.3721, 0.6279])
# correct_example :  tensor([0.3721, 0.6279])
# correct_example :  tensor([0.3728, 0.6272])
# correct_example :  tensor([0.6269, 0.3731])
# correct_example :  tensor([0.3734, 0.6266])
# correct_example :  tensor([0.6266, 0.3734])
# correct_example :  tensor([0.3738, 0.6262])
# correct_example :  tensor([0.6247, 0.3753])
# correct_example :  tensor([0.3758, 0.6242])
# correct_example :  tensor([0.6238, 0.3762])
# correct_example :  tensor([0.6238, 0.3762])
# correct_example :  tensor([0.3763, 0.6237])
# correct_example :  tensor([0.3764, 0.6236])
# correct_example :  tensor([0.3781, 0.6219])
# correct_example :  tensor([0.6219, 0.3781])
# correct_example :  tensor([0.3790, 0.6210])
# correct_example :  tensor([0.6199, 0.3801])
# correct_example :  tensor([0.3801, 0.6199])
# correct_example :  tensor([0.3802, 0.6198])
# correct_example :  tensor([0.3803, 0.6197])
# correct_example :  tensor([0.3803, 0.6197])
# correct_example :  tensor([0.3814, 0.6186])
# correct_example :  tensor([0.6186, 0.3814])
# correct_example :  tensor([0.6185, 0.3815])
# correct_example :  tensor([0.3820, 0.6180])
# correct_example :  tensor([0.3821, 0.6179])
# correct_example :  tensor([0.3824, 0.6176])
# correct_example :  tensor([0.3824, 0.6176])
# correct_example :  tensor([0.6167, 0.3833])
# correct_example :  tensor([0.3835, 0.6165])
# correct_example :  tensor([0.3835, 0.6165])
# correct_example :  tensor([0.3839, 0.6161])
# correct_example :  tensor([0.6159, 0.3841])
# correct_example :  tensor([0.3844, 0.6156])
# correct_example :  tensor([0.3847, 0.6153])
# correct_example :  tensor([0.3849, 0.6151])
# correct_example :  tensor([0.6151, 0.3849])
# correct_example :  tensor([0.3854, 0.6146])
# correct_example :  tensor([0.3856, 0.6144])
# correct_example :  tensor([0.3857, 0.6143])
# correct_example :  tensor([0.3861, 0.6139])
# correct_example :  tensor([0.3861, 0.6139])
# correct_example :  tensor([0.6137, 0.3863])
# correct_example :  tensor([0.3864, 0.6136])
# correct_example :  tensor([0.3865, 0.6135])
# correct_example :  tensor([0.3866, 0.6134])
# correct_example :  tensor([0.6133, 0.3867])
# correct_example :  tensor([0.6127, 0.3873])
# correct_example :  tensor([0.3876, 0.6124])
# correct_example :  tensor([0.3877, 0.6123])
# correct_example :  tensor([0.3877, 0.6123])
# correct_example :  tensor([0.3878, 0.6122])
# correct_example :  tensor([0.6120, 0.3880])
# correct_example :  tensor([0.3881, 0.6119])
# correct_example :  tensor([0.6119, 0.3881])
# correct_example :  tensor([0.3886, 0.6114])
# correct_example :  tensor([0.3888, 0.6112])
# correct_example :  tensor([0.6109, 0.3891])
# correct_example :  tensor([0.6109, 0.3891])
# correct_example :  tensor([0.3892, 0.6108])
# correct_example :  tensor([0.3893, 0.6107])
# correct_example :  tensor([0.6104, 0.3896])
# correct_example :  tensor([0.3897, 0.6103])
# correct_example :  tensor([0.6101, 0.3899])
# correct_example :  tensor([0.3899, 0.6101])
# correct_example :  tensor([0.3899, 0.6101])
# correct_example :  tensor([0.3899, 0.6101])
# correct_example :  tensor([0.3902, 0.6098])
# correct_example :  tensor([0.3903, 0.6097])
# correct_example :  tensor([0.6095, 0.3905])
# correct_example :  tensor([0.3907, 0.6093])
# correct_example :  tensor([0.3913, 0.6087])
# correct_example :  tensor([0.3917, 0.6083])
# correct_example :  tensor([0.3918, 0.6082])
# correct_example :  tensor([0.3920, 0.6080])
# correct_example :  tensor([0.3920, 0.6080])
# correct_example :  tensor([0.6078, 0.3922])
# correct_example :  tensor([0.3923, 0.6077])
# correct_example :  tensor([0.3923, 0.6077])
# correct_example :  tensor([0.3924, 0.6076])
# correct_example :  tensor([0.6075, 0.3925])
# correct_example :  tensor([0.3927, 0.6073])
# correct_example :  tensor([0.3930, 0.6070])
# correct_example :  tensor([0.6066, 0.3934])
# correct_example :  tensor([0.3935, 0.6065])
# correct_example :  tensor([0.3936, 0.6064])
# correct_example :  tensor([0.3937, 0.6063])
# correct_example :  tensor([0.6063, 0.3937])
# correct_example :  tensor([0.3940, 0.6060])
# correct_example :  tensor([0.3940, 0.6060])
# correct_example :  tensor([0.6060, 0.3940])
# correct_example :  tensor([0.3943, 0.6057])
# correct_example :  tensor([0.6052, 0.3948])
# correct_example :  tensor([0.6050, 0.3950])
# correct_example :  tensor([0.3953, 0.6047])
# correct_example :  tensor([0.3958, 0.6042])
# correct_example :  tensor([0.3962, 0.6038])
# correct_example :  tensor([0.3962, 0.6038])
# correct_example :  tensor([0.3964, 0.6036])
# correct_example :  tensor([0.3965, 0.6035])
# correct_example :  tensor([0.3966, 0.6034])
# correct_example :  tensor([0.3966, 0.6034])
# correct_example :  tensor([0.3967, 0.6033])
# correct_example :  tensor([0.3969, 0.6031])
# correct_example :  tensor([0.3972, 0.6028])
# correct_example :  tensor([0.3974, 0.6026])
# correct_example :  tensor([0.3974, 0.6026])
# correct_example :  tensor([0.3975, 0.6025])
# correct_example :  tensor([0.3976, 0.6024])
# correct_example :  tensor([0.3979, 0.6021])
# correct_example :  tensor([0.3979, 0.6021])
# correct_example :  tensor([0.6019, 0.3981])
# correct_example :  tensor([0.3985, 0.6015])
# correct_example :  tensor([0.3986, 0.6014])
# correct_example :  tensor([0.3987, 0.6013])
# correct_example :  tensor([0.3989, 0.6011])
# correct_example :  tensor([0.3990, 0.6010])
# correct_example :  tensor([0.6009, 0.3991])
# correct_example :  tensor([0.3994, 0.6006])
# correct_example :  tensor([0.3995, 0.6005])
# correct_example :  tensor([0.3995, 0.6005])
# correct_example :  tensor([0.3995, 0.6005])
# correct_example :  tensor([0.3998, 0.6002])
# correct_example :  tensor([0.4000, 0.6000])
# correct_example :  tensor([0.5997, 0.4003])
# correct_example :  tensor([0.4004, 0.5996])
# correct_example :  tensor([0.4005, 0.5995])
# correct_example :  tensor([0.5993, 0.4007])
# correct_example :  tensor([0.4007, 0.5993])
# correct_example :  tensor([0.4010, 0.5990])
# correct_example :  tensor([0.4013, 0.5987])
# correct_example :  tensor([0.4018, 0.5982])
# correct_example :  tensor([0.4022, 0.5978])
# correct_example :  tensor([0.4022, 0.5978])
# correct_example :  tensor([0.4022, 0.5978])
# correct_example :  tensor([0.4025, 0.5975])
# correct_example :  tensor([0.4031, 0.5969])
# correct_example :  tensor([0.4031, 0.5969])
# correct_example :  tensor([0.5968, 0.4032])
# correct_example :  tensor([0.4032, 0.5968])
# correct_example :  tensor([0.4032, 0.5968])
# correct_example :  tensor([0.4035, 0.5965])
# correct_example :  tensor([0.4038, 0.5962])
# correct_example :  tensor([0.4046, 0.5954])
# correct_example :  tensor([0.4048, 0.5952])
# correct_example :  tensor([0.4048, 0.5952])
# correct_example :  tensor([0.5951, 0.4049])
# correct_example :  tensor([0.4051, 0.5949])
# correct_example :  tensor([0.4054, 0.5946])
# correct_example :  tensor([0.4058, 0.5942])
# correct_example :  tensor([0.4059, 0.5941])
# correct_example :  tensor([0.4059, 0.5941])
# correct_example :  tensor([0.4060, 0.5940])
# correct_example :  tensor([0.5936, 0.4064])
# correct_example :  tensor([0.4066, 0.5934])
# correct_example :  tensor([0.4072, 0.5928])
# correct_example :  tensor([0.4075, 0.5925])
# correct_example :  tensor([0.4078, 0.5922])
# correct_example :  tensor([0.4078, 0.5922])
# correct_example :  tensor([0.4079, 0.5921])
# correct_example :  tensor([0.4079, 0.5921])
# correct_example :  tensor([0.4082, 0.5918])
# correct_example :  tensor([0.4083, 0.5917])
# correct_example :  tensor([0.5915, 0.4085])
# correct_example :  tensor([0.4087, 0.5913])
# correct_example :  tensor([0.4089, 0.5911])
# correct_example :  tensor([0.4091, 0.5909])
# correct_example :  tensor([0.4097, 0.5903])
# correct_example :  tensor([0.4098, 0.5902])
# correct_example :  tensor([0.4101, 0.5899])
# correct_example :  tensor([0.4102, 0.5898])
# correct_example :  tensor([0.4103, 0.5897])
# correct_example :  tensor([0.4104, 0.5896])
# correct_example :  tensor([0.4105, 0.5895])
# correct_example :  tensor([0.4105, 0.5895])
# correct_example :  tensor([0.4106, 0.5894])
# correct_example :  tensor([0.4107, 0.5893])
# correct_example :  tensor([0.5893, 0.4107])
# correct_example :  tensor([0.4107, 0.5893])
# correct_example :  tensor([0.4108, 0.5892])
# correct_example :  tensor([0.4110, 0.5890])
# correct_example :  tensor([0.4113, 0.5887])
# correct_example :  tensor([0.5886, 0.4114])
# correct_example :  tensor([0.4116, 0.5884])
# correct_example :  tensor([0.5880, 0.4120])
# correct_example :  tensor([0.4121, 0.5879])
# correct_example :  tensor([0.4121, 0.5879])
# correct_example :  tensor([0.4122, 0.5878])
# correct_example :  tensor([0.4125, 0.5875])
# correct_example :  tensor([0.5874, 0.4126])
# correct_example :  tensor([0.4126, 0.5874])
# correct_example :  tensor([0.4126, 0.5874])
# correct_example :  tensor([0.4127, 0.5873])
# correct_example :  tensor([0.4129, 0.5871])
# correct_example :  tensor([0.4130, 0.5870])
# correct_example :  tensor([0.4131, 0.5869])
# correct_example :  tensor([0.4132, 0.5868])
# correct_example :  tensor([0.4135, 0.5865])
# correct_example :  tensor([0.4135, 0.5865])
# correct_example :  tensor([0.4135, 0.5865])
# correct_example :  tensor([0.4137, 0.5863])
# correct_example :  tensor([0.4137, 0.5863])
# correct_example :  tensor([0.4138, 0.5862])
# correct_example :  tensor([0.4140, 0.5860])
# correct_example :  tensor([0.4141, 0.5859])
# correct_example :  tensor([0.4141, 0.5859])
# correct_example :  tensor([0.5859, 0.4141])
# correct_example :  tensor([0.5859, 0.4141])
# correct_example :  tensor([0.4144, 0.5856])
# correct_example :  tensor([0.4145, 0.5855])
# correct_example :  tensor([0.4149, 0.5851])
# correct_example :  tensor([0.4153, 0.5847])
# correct_example :  tensor([0.4155, 0.5845])
# correct_example :  tensor([0.4155, 0.5845])
# correct_example :  tensor([0.4156, 0.5844])
# correct_example :  tensor([0.4157, 0.5843])
# correct_example :  tensor([0.4159, 0.5841])
# correct_example :  tensor([0.4162, 0.5838])
# correct_example :  tensor([0.4162, 0.5838])
# correct_example :  tensor([0.4162, 0.5838])
# correct_example :  tensor([0.4162, 0.5838])
# correct_example :  tensor([0.4163, 0.5837])
# correct_example :  tensor([0.4166, 0.5834])
# correct_example :  tensor([0.4168, 0.5832])
# correct_example :  tensor([0.4169, 0.5831])
# correct_example :  tensor([0.4172, 0.5828])
# correct_example :  tensor([0.5827, 0.4173])
# correct_example :  tensor([0.4175, 0.5825])
# correct_example :  tensor([0.4175, 0.5825])
# correct_example :  tensor([0.4179, 0.5821])
# correct_example :  tensor([0.4181, 0.5819])
# correct_example :  tensor([0.4181, 0.5819])
# correct_example :  tensor([0.4186, 0.5814])
# correct_example :  tensor([0.4186, 0.5814])
# correct_example :  tensor([0.4187, 0.5813])
# correct_example :  tensor([0.4188, 0.5812])
# correct_example :  tensor([0.5811, 0.4189])
# correct_example :  tensor([0.4191, 0.5809])
# correct_example :  tensor([0.4194, 0.5806])
# correct_example :  tensor([0.4195, 0.5805])
# correct_example :  tensor([0.4199, 0.5801])
# correct_example :  tensor([0.4199, 0.5801])
# correct_example :  tensor([0.4199, 0.5801])
# correct_example :  tensor([0.4201, 0.5799])
# correct_example :  tensor([0.4204, 0.5796])
# correct_example :  tensor([0.4206, 0.5794])
# correct_example :  tensor([0.4209, 0.5791])
# correct_example :  tensor([0.4212, 0.5788])
# correct_example :  tensor([0.4212, 0.5788])
# correct_example :  tensor([0.4213, 0.5787])
# correct_example :  tensor([0.4215, 0.5785])
# correct_example :  tensor([0.4216, 0.5784])
# correct_example :  tensor([0.4216, 0.5784])
# correct_example :  tensor([0.4217, 0.5783])
# correct_example :  tensor([0.4218, 0.5782])
# correct_example :  tensor([0.4218, 0.5782])
# correct_example :  tensor([0.4218, 0.5782])
# correct_example :  tensor([0.4222, 0.5778])
# correct_example :  tensor([0.5774, 0.4226])
# correct_example :  tensor([0.4227, 0.5773])
# correct_example :  tensor([0.5773, 0.4227])
# correct_example :  tensor([0.4228, 0.5772])
# correct_example :  tensor([0.4233, 0.5767])
# correct_example :  tensor([0.4234, 0.5766])
# correct_example :  tensor([0.4236, 0.5764])
# correct_example :  tensor([0.4239, 0.5761])
# correct_example :  tensor([0.4239, 0.5761])
# correct_example :  tensor([0.4242, 0.5758])
# correct_example :  tensor([0.5757, 0.4243])
# correct_example :  tensor([0.5751, 0.4249])
# correct_example :  tensor([0.4249, 0.5751])
# correct_example :  tensor([0.5750, 0.4250])
# correct_example :  tensor([0.5748, 0.4252])
# correct_example :  tensor([0.4253, 0.5747])
# correct_example :  tensor([0.4258, 0.5742])
# correct_example :  tensor([0.4259, 0.5741])
# correct_example :  tensor([0.4260, 0.5740])
# correct_example :  tensor([0.4263, 0.5737])
# correct_example :  tensor([0.4264, 0.5736])
# correct_example :  tensor([0.5729, 0.4271])
# correct_example :  tensor([0.4273, 0.5727])
# correct_example :  tensor([0.4277, 0.5723])
# correct_example :  tensor([0.4283, 0.5717])
# correct_example :  tensor([0.5715, 0.4285])
# correct_example :  tensor([0.4288, 0.5712])
# correct_example :  tensor([0.4292, 0.5708])
# correct_example :  tensor([0.4294, 0.5706])
# correct_example :  tensor([0.4296, 0.5704])
# correct_example :  tensor([0.5703, 0.4297])
# correct_example :  tensor([0.4298, 0.5702])
# correct_example :  tensor([0.4299, 0.5701])
# correct_example :  tensor([0.4300, 0.5700])
# correct_example :  tensor([0.4304, 0.5696])
# correct_example :  tensor([0.5696, 0.4304])
# correct_example :  tensor([0.4306, 0.5694])
# correct_example :  tensor([0.4306, 0.5694])
# correct_example :  tensor([0.4307, 0.5693])
# correct_example :  tensor([0.5686, 0.4314])
# correct_example :  tensor([0.4314, 0.5686])
# correct_example :  tensor([0.4318, 0.5682])
# correct_example :  tensor([0.4320, 0.5680])
# correct_example :  tensor([0.5677, 0.4323])
# correct_example :  tensor([0.4325, 0.5675])
# correct_example :  tensor([0.4327, 0.5673])
# correct_example :  tensor([0.4328, 0.5672])
# correct_example :  tensor([0.4331, 0.5669])
# correct_example :  tensor([0.4333, 0.5667])
# correct_example :  tensor([0.5665, 0.4335])
# correct_example :  tensor([0.4336, 0.5664])
# correct_example :  tensor([0.4336, 0.5664])
# correct_example :  tensor([0.4340, 0.5660])
# correct_example :  tensor([0.4341, 0.5659])
# correct_example :  tensor([0.4342, 0.5658])
# correct_example :  tensor([0.4343, 0.5657])
# correct_example :  tensor([0.4343, 0.5657])
# correct_example :  tensor([0.4346, 0.5654])
# correct_example :  tensor([0.4350, 0.5650])
# correct_example :  tensor([0.4351, 0.5649])
# correct_example :  tensor([0.4352, 0.5648])
# correct_example :  tensor([0.5643, 0.4357])
# correct_example :  tensor([0.4357, 0.5643])
# correct_example :  tensor([0.4363, 0.5637])
# correct_example :  tensor([0.5637, 0.4363])
# correct_example :  tensor([0.4364, 0.5636])
# correct_example :  tensor([0.4368, 0.5632])
# correct_example :  tensor([0.4372, 0.5628])
# correct_example :  tensor([0.4372, 0.5628])
# correct_example :  tensor([0.5626, 0.4374])
# correct_example :  tensor([0.4374, 0.5626])
# correct_example :  tensor([0.4374, 0.5626])
# correct_example :  tensor([0.4374, 0.5626])
# correct_example :  tensor([0.4376, 0.5624])
# correct_example :  tensor([0.4378, 0.5622])
# correct_example :  tensor([0.4380, 0.5620])
# correct_example :  tensor([0.5617, 0.4383])
# correct_example :  tensor([0.5614, 0.4386])
# correct_example :  tensor([0.4387, 0.5613])
# correct_example :  tensor([0.5609, 0.4391])
# correct_example :  tensor([0.4395, 0.5605])
# correct_example :  tensor([0.5602, 0.4398])
# correct_example :  tensor([0.4399, 0.5601])
# correct_example :  tensor([0.5599, 0.4401])
# correct_example :  tensor([0.4402, 0.5598])
# correct_example :  tensor([0.4403, 0.5597])
# correct_example :  tensor([0.4406, 0.5594])
# correct_example :  tensor([0.5591, 0.4409])
# correct_example :  tensor([0.5589, 0.4411])
# correct_example :  tensor([0.4412, 0.5588])
# correct_example :  tensor([0.4413, 0.5587])
# correct_example :  tensor([0.4413, 0.5587])
# correct_example :  tensor([0.5581, 0.4419])
# correct_example :  tensor([0.4424, 0.5576])
# correct_example :  tensor([0.4426, 0.5574])
# correct_example :  tensor([0.4426, 0.5574])
# correct_example :  tensor([0.5568, 0.4432])
# correct_example :  tensor([0.4441, 0.5559])
# correct_example :  tensor([0.4444, 0.5556])
# correct_example :  tensor([0.4445, 0.5555])
# correct_example :  tensor([0.4450, 0.5550])
# correct_example :  tensor([0.4450, 0.5550])
# correct_example :  tensor([0.4455, 0.5545])
# correct_example :  tensor([0.4458, 0.5542])
# correct_example :  tensor([0.5539, 0.4461])
# correct_example :  tensor([0.4461, 0.5539])
# correct_example :  tensor([0.4462, 0.5538])
# correct_example :  tensor([0.4463, 0.5537])
# correct_example :  tensor([0.4464, 0.5536])
# correct_example :  tensor([0.5528, 0.4472])
# correct_example :  tensor([0.4475, 0.5525])
# correct_example :  tensor([0.4482, 0.5518])
# correct_example :  tensor([0.4485, 0.5515])
# correct_example :  tensor([0.4490, 0.5510])
# correct_example :  tensor([0.5508, 0.4492])
# correct_example :  tensor([0.5507, 0.4493])
# correct_example :  tensor([0.5504, 0.4496])
# correct_example :  tensor([0.4497, 0.5503])
# correct_example :  tensor([0.5502, 0.4498])
# correct_example :  tensor([0.4500, 0.5500])
# correct_example :  tensor([0.4502, 0.5498])
# correct_example :  tensor([0.4505, 0.5495])
# correct_example :  tensor([0.4510, 0.5490])
# correct_example :  tensor([0.5489, 0.4511])
# correct_example :  tensor([0.4514, 0.5486])
# correct_example :  tensor([0.5485, 0.4515])
# correct_example :  tensor([0.4525, 0.5475])
# correct_example :  tensor([0.5470, 0.4530])
# correct_example :  tensor([0.4532, 0.5468])
# correct_example :  tensor([0.4534, 0.5466])
# correct_example :  tensor([0.5465, 0.4535])
# correct_example :  tensor([0.4538, 0.5462])
# correct_example :  tensor([0.4540, 0.5460])
# correct_example :  tensor([0.4548, 0.5452])
# correct_example :  tensor([0.5452, 0.4548])
# correct_example :  tensor([0.5449, 0.4551])
# correct_example :  tensor([0.4551, 0.5449])
# correct_example :  tensor([0.4551, 0.5449])
# correct_example :  tensor([0.5448, 0.4552])
# correct_example :  tensor([0.5445, 0.4555])
# correct_example :  tensor([0.4556, 0.5444])
# correct_example :  tensor([0.5444, 0.4556])
# correct_example :  tensor([0.4556, 0.5444])
# correct_example :  tensor([0.5442, 0.4558])
# correct_example :  tensor([0.4559, 0.5441])
# correct_example :  tensor([0.5441, 0.4559])
# correct_example :  tensor([0.4559, 0.5441])
# correct_example :  tensor([0.4565, 0.5435])
# correct_example :  tensor([0.4565, 0.5435])
# correct_example :  tensor([0.4566, 0.5434])
# correct_example :  tensor([0.4567, 0.5433])
# correct_example :  tensor([0.5430, 0.4570])
# correct_example :  tensor([0.4574, 0.5426])
# correct_example :  tensor([0.4578, 0.5422])
# correct_example :  tensor([0.4578, 0.5422])
# correct_example :  tensor([0.4580, 0.5420])
# correct_example :  tensor([0.4581, 0.5419])
# correct_example :  tensor([0.4583, 0.5417])
# correct_example :  tensor([0.5416, 0.4584])
# correct_example :  tensor([0.4584, 0.5416])
# correct_example :  tensor([0.4589, 0.5411])
# correct_example :  tensor([0.4591, 0.5409])
# correct_example :  tensor([0.4591, 0.5409])
# correct_example :  tensor([0.4592, 0.5408])
# correct_example :  tensor([0.4593, 0.5407])
# correct_example :  tensor([0.4594, 0.5406])
# correct_example :  tensor([0.4598, 0.5402])
# correct_example :  tensor([0.5398, 0.4602])
# correct_example :  tensor([0.4605, 0.5395])
# correct_example :  tensor([0.4615, 0.5385])
# correct_example :  tensor([0.4618, 0.5382])
# correct_example :  tensor([0.4622, 0.5378])
# correct_example :  tensor([0.5377, 0.4623])
# correct_example :  tensor([0.4623, 0.5377])
# correct_example :  tensor([0.4624, 0.5376])
# correct_example :  tensor([0.4624, 0.5376])
# correct_example :  tensor([0.5374, 0.4626])
# correct_example :  tensor([0.4635, 0.5365])
# correct_example :  tensor([0.4635, 0.5365])
# correct_example :  tensor([0.4638, 0.5362])
# correct_example :  tensor([0.4644, 0.5356])
# correct_example :  tensor([0.4645, 0.5355])
# correct_example :  tensor([0.5354, 0.4646])
# correct_example :  tensor([0.4647, 0.5353])
# correct_example :  tensor([0.5352, 0.4648])
# correct_example :  tensor([0.4655, 0.5345])
# correct_example :  tensor([0.4663, 0.5337])
# correct_example :  tensor([0.4664, 0.5336])
# correct_example :  tensor([0.4664, 0.5336])
# correct_example :  tensor([0.4668, 0.5332])
# correct_example :  tensor([0.4673, 0.5327])
# correct_example :  tensor([0.5324, 0.4676])
# correct_example :  tensor([0.5321, 0.4679])
# correct_example :  tensor([0.5320, 0.4680])
# correct_example :  tensor([0.4683, 0.5317])
# correct_example :  tensor([0.4688, 0.5312])
# correct_example :  tensor([0.5302, 0.4698])
# correct_example :  tensor([0.4699, 0.5301])
# correct_example :  tensor([0.4702, 0.5298])
# correct_example :  tensor([0.4702, 0.5298])
# correct_example :  tensor([0.5298, 0.4702])
# correct_example :  tensor([0.4703, 0.5297])
# correct_example :  tensor([0.5294, 0.4706])
# correct_example :  tensor([0.5294, 0.4706])
# correct_example :  tensor([0.5291, 0.4709])
# correct_example :  tensor([0.4710, 0.5290])
# correct_example :  tensor([0.4714, 0.5286])
# correct_example :  tensor([0.5280, 0.4720])
# correct_example :  tensor([0.4721, 0.5279])
# correct_example :  tensor([0.4724, 0.5276])
# correct_example :  tensor([0.4726, 0.5274])
# correct_example :  tensor([0.5264, 0.4736])
# correct_example :  tensor([0.4737, 0.5263])
# correct_example :  tensor([0.4740, 0.5260])
# correct_example :  tensor([0.4745, 0.5255])
# correct_example :  tensor([0.5254, 0.4746])
# correct_example :  tensor([0.4750, 0.5250])
# correct_example :  tensor([0.4755, 0.5245])
# correct_example :  tensor([0.4759, 0.5241])
# correct_example :  tensor([0.4761, 0.5239])
# correct_example :  tensor([0.4761, 0.5239])
# correct_example :  tensor([0.4762, 0.5238])
# correct_example :  tensor([0.4763, 0.5237])
# correct_example :  tensor([0.4766, 0.5234])
# correct_example :  tensor([0.4766, 0.5234])
# correct_example :  tensor([0.4775, 0.5225])
# correct_example :  tensor([0.4786, 0.5214])
# correct_example :  tensor([0.5200, 0.4800])
# correct_example :  tensor([0.5193, 0.4807])
# correct_example :  tensor([0.5190, 0.4810])
# correct_example :  tensor([0.4812, 0.5188])
# correct_example :  tensor([0.4812, 0.5188])
# correct_example :  tensor([0.5186, 0.4814])
# correct_example :  tensor([0.5179, 0.4821])
# correct_example :  tensor([0.4821, 0.5179])
# correct_example :  tensor([0.5177, 0.4823])
# correct_example :  tensor([0.4833, 0.5167])
# correct_example :  tensor([0.4834, 0.5166])
# correct_example :  tensor([0.4839, 0.5161])
# correct_example :  tensor([0.5153, 0.4847])
# correct_example :  tensor([0.4849, 0.5151])
# correct_example :  tensor([0.4851, 0.5149])
# correct_example :  tensor([0.4853, 0.5147])
# correct_example :  tensor([0.5146, 0.4854])
# correct_example :  tensor([0.4854, 0.5146])
# correct_example :  tensor([0.4860, 0.5140])
# correct_example :  tensor([0.5136, 0.4864])
# correct_example :  tensor([0.4866, 0.5134])
# correct_example :  tensor([0.5133, 0.4867])
# correct_example :  tensor([0.4872, 0.5128])
# correct_example :  tensor([0.5127, 0.4873])
# correct_example :  tensor([0.4875, 0.5125])
# correct_example :  tensor([0.5125, 0.4875])
# correct_example :  tensor([0.4880, 0.5120])
# correct_example :  tensor([0.5118, 0.4882])
# correct_example :  tensor([0.4883, 0.5117])
# correct_example :  tensor([0.4885, 0.5115])
# correct_example :  tensor([0.5111, 0.4889])
# correct_example :  tensor([0.4891, 0.5109])
# correct_example :  tensor([0.4901, 0.5099])
# correct_example :  tensor([0.4910, 0.5090])
# correct_example :  tensor([0.4911, 0.5089])
# correct_example :  tensor([0.5087, 0.4913])
# correct_example :  tensor([0.5082, 0.4918])
# correct_example :  tensor([0.5080, 0.4920])
# correct_example :  tensor([0.5078, 0.4922])
# correct_example :  tensor([0.4924, 0.5076])
# correct_example :  tensor([0.5076, 0.4924])
# correct_example :  tensor([0.4932, 0.5068])
# correct_example :  tensor([0.5065, 0.4935])
# correct_example :  tensor([0.5064, 0.4936])
# correct_example :  tensor([0.4943, 0.5057])
# correct_example :  tensor([0.5042, 0.4958])
# correct_example :  tensor([0.4965, 0.5035])
# correct_example :  tensor([0.4969, 0.5031])
# correct_example :  tensor([0.4972, 0.5028])
# correct_example :  tensor([0.4972, 0.5028])
# correct_example :  tensor([0.4985, 0.5015])
# correct_example :  tensor([0.5013, 0.4987])
# wrong_example :  tensor([0.8339, 0.1661])
# wrong_example :  tensor([0.8108, 0.1892])
# wrong_example :  tensor([0.8095, 0.1905])
# wrong_example :  tensor([0.7939, 0.2061])
# wrong_example :  tensor([0.7916, 0.2084])
# wrong_example :  tensor([0.7888, 0.2112])
# wrong_example :  tensor([0.7773, 0.2227])
# wrong_example :  tensor([0.7670, 0.2330])
# wrong_example :  tensor([0.7660, 0.2340])
# wrong_example :  tensor([0.7516, 0.2484])
# wrong_example :  tensor([0.7512, 0.2488])
# wrong_example :  tensor([0.7402, 0.2598])
# wrong_example :  tensor([0.7329, 0.2671])
# wrong_example :  tensor([0.7180, 0.2820])
# wrong_example :  tensor([0.7132, 0.2868])
# wrong_example :  tensor([0.7103, 0.2897])
# wrong_example :  tensor([0.7095, 0.2905])
# wrong_example :  tensor([0.7048, 0.2952])
# wrong_example :  tensor([0.6977, 0.3023])
# wrong_example :  tensor([0.6959, 0.3041])
# wrong_example :  tensor([0.6854, 0.3146])
# wrong_example :  tensor([0.6803, 0.3197])
# wrong_example :  tensor([0.6785, 0.3215])
# wrong_example :  tensor([0.6782, 0.3218])
# wrong_example :  tensor([0.6763, 0.3237])
# wrong_example :  tensor([0.6761, 0.3239])
# wrong_example :  tensor([0.6752, 0.3248])
# wrong_example :  tensor([0.6744, 0.3256])
# wrong_example :  tensor([0.6711, 0.3289])
# wrong_example :  tensor([0.6710, 0.3290])
# wrong_example :  tensor([0.6684, 0.3316])
# wrong_example :  tensor([0.6670, 0.3330])
# wrong_example :  tensor([0.6666, 0.3334])
# wrong_example :  tensor([0.6645, 0.3355])
# wrong_example :  tensor([0.6630, 0.3370])
# wrong_example :  tensor([0.6614, 0.3386])
# wrong_example :  tensor([0.6604, 0.3396])
# wrong_example :  tensor([0.6477, 0.3523])
# wrong_example :  tensor([0.6472, 0.3528])
# wrong_example :  tensor([0.6455, 0.3545])
# wrong_example :  tensor([0.6444, 0.3556])
# wrong_example :  tensor([0.6440, 0.3560])
# wrong_example :  tensor([0.6377, 0.3623])
# wrong_example :  tensor([0.6376, 0.3624])
# wrong_example :  tensor([0.3627, 0.6373])
# wrong_example :  tensor([0.6370, 0.3630])
# wrong_example :  tensor([0.6341, 0.3659])
# wrong_example :  tensor([0.6331, 0.3669])
# wrong_example :  tensor([0.6326, 0.3674])
# wrong_example :  tensor([0.6311, 0.3689])
# wrong_example :  tensor([0.6294, 0.3706])
# wrong_example :  tensor([0.3717, 0.6283])
# wrong_example :  tensor([0.3733, 0.6267])
# wrong_example :  tensor([0.3736, 0.6264])
# wrong_example :  tensor([0.6263, 0.3737])
# wrong_example :  tensor([0.3744, 0.6256])
# wrong_example :  tensor([0.6233, 0.3767])
# wrong_example :  tensor([0.6185, 0.3815])
# wrong_example :  tensor([0.6177, 0.3823])
# wrong_example :  tensor([0.3827, 0.6173])
# wrong_example :  tensor([0.6171, 0.3829])
# wrong_example :  tensor([0.3829, 0.6171])
# wrong_example :  tensor([0.6165, 0.3835])
# wrong_example :  tensor([0.3837, 0.6163])
# wrong_example :  tensor([0.3839, 0.6161])
# wrong_example :  tensor([0.6160, 0.3840])
# wrong_example :  tensor([0.6158, 0.3842])
# wrong_example :  tensor([0.3864, 0.6136])
# wrong_example :  tensor([0.6119, 0.3881])
# wrong_example :  tensor([0.3900, 0.6100])
# wrong_example :  tensor([0.3904, 0.6096])
# wrong_example :  tensor([0.6088, 0.3912])
# wrong_example :  tensor([0.3915, 0.6085])
# wrong_example :  tensor([0.3944, 0.6056])
# wrong_example :  tensor([0.3959, 0.6041])
# wrong_example :  tensor([0.3963, 0.6037])
# wrong_example :  tensor([0.6034, 0.3966])
# wrong_example :  tensor([0.6028, 0.3972])
# wrong_example :  tensor([0.3977, 0.6023])
# wrong_example :  tensor([0.6018, 0.3982])
# wrong_example :  tensor([0.3983, 0.6017])
# wrong_example :  tensor([0.3991, 0.6009])
# wrong_example :  tensor([0.6009, 0.3991])
# wrong_example :  tensor([0.5997, 0.4003])
# wrong_example :  tensor([0.4020, 0.5980])
# wrong_example :  tensor([0.4021, 0.5979])
# wrong_example :  tensor([0.4024, 0.5976])
# wrong_example :  tensor([0.4029, 0.5971])
# wrong_example :  tensor([0.4031, 0.5969])
# wrong_example :  tensor([0.4036, 0.5964])
# wrong_example :  tensor([0.5963, 0.4037])
# wrong_example :  tensor([0.4042, 0.5958])
# wrong_example :  tensor([0.4042, 0.5958])
# wrong_example :  tensor([0.5954, 0.4046])
# wrong_example :  tensor([0.4067, 0.5933])
# wrong_example :  tensor([0.4069, 0.5931])
# wrong_example :  tensor([0.5914, 0.4086])
# wrong_example :  tensor([0.4092, 0.5908])
# wrong_example :  tensor([0.4095, 0.5905])
# wrong_example :  tensor([0.5888, 0.4112])
# wrong_example :  tensor([0.5885, 0.4115])
# wrong_example :  tensor([0.5871, 0.4129])
# wrong_example :  tensor([0.4131, 0.5869])
# wrong_example :  tensor([0.4134, 0.5866])
# wrong_example :  tensor([0.4136, 0.5864])
# wrong_example :  tensor([0.4141, 0.5859])
# wrong_example :  tensor([0.4152, 0.5848])
# wrong_example :  tensor([0.5847, 0.4153])
# wrong_example :  tensor([0.4155, 0.5845])
# wrong_example :  tensor([0.4171, 0.5829])
# wrong_example :  tensor([0.4174, 0.5826])
# wrong_example :  tensor([0.4175, 0.5825])
# wrong_example :  tensor([0.4185, 0.5815])
# wrong_example :  tensor([0.4191, 0.5809])
# wrong_example :  tensor([0.4196, 0.5804])
# wrong_example :  tensor([0.5803, 0.4197])
# wrong_example :  tensor([0.4209, 0.5791])
# wrong_example :  tensor([0.4211, 0.5789])
# wrong_example :  tensor([0.4212, 0.5788])
# wrong_example :  tensor([0.4215, 0.5785])
# wrong_example :  tensor([0.4223, 0.5777])
# wrong_example :  tensor([0.4225, 0.5775])
# wrong_example :  tensor([0.4226, 0.5774])
# wrong_example :  tensor([0.5774, 0.4226])
# wrong_example :  tensor([0.4245, 0.5755])
# wrong_example :  tensor([0.4245, 0.5755])
# wrong_example :  tensor([0.5753, 0.4247])
# wrong_example :  tensor([0.5748, 0.4252])
# wrong_example :  tensor([0.5745, 0.4255])
# wrong_example :  tensor([0.4257, 0.5743])
# wrong_example :  tensor([0.4265, 0.5735])
# wrong_example :  tensor([0.4265, 0.5735])
# wrong_example :  tensor([0.4266, 0.5734])
# wrong_example :  tensor([0.4276, 0.5724])
# wrong_example :  tensor([0.5708, 0.4292])
# wrong_example :  tensor([0.4294, 0.5706])
# wrong_example :  tensor([0.4302, 0.5698])
# wrong_example :  tensor([0.5695, 0.4305])
# wrong_example :  tensor([0.4309, 0.5691])
# wrong_example :  tensor([0.4309, 0.5691])
# wrong_example :  tensor([0.5690, 0.4310])
# wrong_example :  tensor([0.5690, 0.4310])
# wrong_example :  tensor([0.4312, 0.5688])
# wrong_example :  tensor([0.4323, 0.5677])
# wrong_example :  tensor([0.5660, 0.4340])
# wrong_example :  tensor([0.4345, 0.5655])
# wrong_example :  tensor([0.4346, 0.5654])
# wrong_example :  tensor([0.4352, 0.5648])
# wrong_example :  tensor([0.4356, 0.5644])
# wrong_example :  tensor([0.4358, 0.5642])
# wrong_example :  tensor([0.4359, 0.5641])
# wrong_example :  tensor([0.5640, 0.4360])
# wrong_example :  tensor([0.4370, 0.5630])
# wrong_example :  tensor([0.4371, 0.5629])
# wrong_example :  tensor([0.5628, 0.4372])
# wrong_example :  tensor([0.4372, 0.5628])
# wrong_example :  tensor([0.5618, 0.4382])
# wrong_example :  tensor([0.4391, 0.5609])
# wrong_example :  tensor([0.5595, 0.4405])
# wrong_example :  tensor([0.5590, 0.4410])
# wrong_example :  tensor([0.4419, 0.5581])
# wrong_example :  tensor([0.4422, 0.5578])
# wrong_example :  tensor([0.4423, 0.5577])
# wrong_example :  tensor([0.4426, 0.5574])
# wrong_example :  tensor([0.4427, 0.5573])
# wrong_example :  tensor([0.4433, 0.5567])
# wrong_example :  tensor([0.4434, 0.5566])
# wrong_example :  tensor([0.4438, 0.5562])
# wrong_example :  tensor([0.5549, 0.4451])
# wrong_example :  tensor([0.4454, 0.5546])
# wrong_example :  tensor([0.5545, 0.4455])
# wrong_example :  tensor([0.4458, 0.5542])
# wrong_example :  tensor([0.5537, 0.4463])
# wrong_example :  tensor([0.4464, 0.5536])
# wrong_example :  tensor([0.4465, 0.5535])
# wrong_example :  tensor([0.4473, 0.5527])
# wrong_example :  tensor([0.4476, 0.5524])
# wrong_example :  tensor([0.4482, 0.5518])
# wrong_example :  tensor([0.5506, 0.4494])
# wrong_example :  tensor([0.5504, 0.4496])
# wrong_example :  tensor([0.4496, 0.5504])
# wrong_example :  tensor([0.4498, 0.5502])
# wrong_example :  tensor([0.5500, 0.4500])
# wrong_example :  tensor([0.5500, 0.4500])
# wrong_example :  tensor([0.5495, 0.4505])
# wrong_example :  tensor([0.5494, 0.4506])
# wrong_example :  tensor([0.5493, 0.4507])
# wrong_example :  tensor([0.4512, 0.5488])
# wrong_example :  tensor([0.5488, 0.4512])
# wrong_example :  tensor([0.4514, 0.5486])
# wrong_example :  tensor([0.5466, 0.4534])
# wrong_example :  tensor([0.4541, 0.5459])
# wrong_example :  tensor([0.4544, 0.5456])
# wrong_example :  tensor([0.4548, 0.5452])
# wrong_example :  tensor([0.4554, 0.5446])
# wrong_example :  tensor([0.4568, 0.5432])
# wrong_example :  tensor([0.4569, 0.5431])
# wrong_example :  tensor([0.5426, 0.4574])
# wrong_example :  tensor([0.4575, 0.5425])
# wrong_example :  tensor([0.4585, 0.5415])
# wrong_example :  tensor([0.4597, 0.5403])
# wrong_example :  tensor([0.5393, 0.4607])
# wrong_example :  tensor([0.4607, 0.5393])
# wrong_example :  tensor([0.5391, 0.4609])
# wrong_example :  tensor([0.4610, 0.5390])
# wrong_example :  tensor([0.4629, 0.5371])
# wrong_example :  tensor([0.5371, 0.4629])
# wrong_example :  tensor([0.4634, 0.5366])
# wrong_example :  tensor([0.5364, 0.4636])
# wrong_example :  tensor([0.5351, 0.4649])
# wrong_example :  tensor([0.5348, 0.4652])
# wrong_example :  tensor([0.4656, 0.5344])
# wrong_example :  tensor([0.4664, 0.5336])
# wrong_example :  tensor([0.5332, 0.4668])
# wrong_example :  tensor([0.5332, 0.4668])
# wrong_example :  tensor([0.5308, 0.4692])
# wrong_example :  tensor([0.5308, 0.4692])
# wrong_example :  tensor([0.4694, 0.5306])
# wrong_example :  tensor([0.4711, 0.5289])
# wrong_example :  tensor([0.5280, 0.4720])
# wrong_example :  tensor([0.4720, 0.5280])
# wrong_example :  tensor([0.5269, 0.4731])
# wrong_example :  tensor([0.5268, 0.4732])
# wrong_example :  tensor([0.4735, 0.5265])
# wrong_example :  tensor([0.5255, 0.4745])
# wrong_example :  tensor([0.5251, 0.4749])
# wrong_example :  tensor([0.4754, 0.5246])
# wrong_example :  tensor([0.5246, 0.4754])
# wrong_example :  tensor([0.5242, 0.4758])
# wrong_example :  tensor([0.5238, 0.4762])
# wrong_example :  tensor([0.4786, 0.5214])
# wrong_example :  tensor([0.5214, 0.4786])
# wrong_example :  tensor([0.4788, 0.5212])
# wrong_example :  tensor([0.5212, 0.4788])
# wrong_example :  tensor([0.4789, 0.5211])
# wrong_example :  tensor([0.4790, 0.5210])
# wrong_example :  tensor([0.5194, 0.4806])
# wrong_example :  tensor([0.5191, 0.4809])
# wrong_example :  tensor([0.4813, 0.5187])
# wrong_example :  tensor([0.4818, 0.5182])
# wrong_example :  tensor([0.4820, 0.5180])
# wrong_example :  tensor([0.4827, 0.5173])
# wrong_example :  tensor([0.5166, 0.4834])
# wrong_example :  tensor([0.5161, 0.4839])
# wrong_example :  tensor([0.5156, 0.4844])
# wrong_example :  tensor([0.5155, 0.4845])
# wrong_example :  tensor([0.5148, 0.4852])
# wrong_example :  tensor([0.4865, 0.5135])
# wrong_example :  tensor([0.4870, 0.5130])
# wrong_example :  tensor([0.4882, 0.5118])
# wrong_example :  tensor([0.5114, 0.4886])
# wrong_example :  tensor([0.5113, 0.4887])
# wrong_example :  tensor([0.5107, 0.4893])
# wrong_example :  tensor([0.4894, 0.5106])
# wrong_example :  tensor([0.4897, 0.5103])
# wrong_example :  tensor([0.4900, 0.5100])
# wrong_example :  tensor([0.5099, 0.4901])
# wrong_example :  tensor([0.5097, 0.4903])
# wrong_example :  tensor([0.4907, 0.5093])
# wrong_example :  tensor([0.4921, 0.5079])
# wrong_example :  tensor([0.4943, 0.5057])
# wrong_example :  tensor([0.4947, 0.5053])
# wrong_example :  tensor([0.5049, 0.4951])
# wrong_example :  tensor([0.4953, 0.5047])
# wrong_example :  tensor([0.5042, 0.4958])
# wrong_example :  tensor([0.5041, 0.4959])
# wrong_example :  tensor([0.5037, 0.4963])
# wrong_example :  tensor([0.4966, 0.5034])
# wrong_example :  tensor([0.5030, 0.4970])
# wrong_example :  tensor([0.5029, 0.4971])
# wrong_example :  tensor([0.5019, 0.4981])
# wrong_example :  tensor([0.5017, 0.4983])
# wrong_example :  tensor([0.5016, 0.4984])
# wrong_example :  tensor([0.4987, 0.5013])
# wrong_example :  tensor([0.4987, 0.5013])
# wrong_example :  tensor([0.5000, 0.5000])

# %%
classes = test_dataset.classes
n_images = 5
plot_most_correct_wrong(correct_examples, wrong_examples, classes, n_images)
